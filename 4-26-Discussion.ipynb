# %% [markdown]
# <a href="https://colab.research.google.com/github/jonchang153/git-practice/blob/main/4-26-Discussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# made a change using github - colab interface
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# ## Importing a library

# %%
# !pip install matplotlib-venn
import matplotlib_venn

# %%
# !pip install plotly==5.7.0
# Out:
# ...
#      |████████████████████████████████| 28.8 MB 1.8 MB/s
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ...

# %%
# !apt-get <package name>  --- another way to import package

# %% [markdown]
# ## File Upload

# %% [markdown]
# ## From local system

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-cc872951-e597-4248-813a-08d7878724c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc872951-e597-4248-813a-08d7878724c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# # From GDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/'
# Out:
# /content/drive/MyDrive

# %%
results_df.to_csv ('')

# %% [markdown]
# ## Interacting with Github

# %% [markdown]
# ## Save to github

# %% [markdown]
# ## Open from github

# %% [markdown]
# http://colab.research.google.com/github

# %% [markdown]
# ## Connecting to GPU

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
